# %%
# %matplotlib inline
    
import pandas as pd

# %%
df = pd.read_csv('sports.csv', index_col=0)
df
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df.plot(kind = 'bar')

# %%
#가로
df.plot(kind = 'barh')

# %%
df.plot(kind = 'bar', stacked=True)

# %%
#여성만을 대상으로 한 막대그래프
df['Female'].plot(kind='bar')
